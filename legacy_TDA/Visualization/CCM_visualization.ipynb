# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
dctry='/home/morteza/dlc_projects/Analysis/Currencodes/TDA/Visualization/CCM/'

flatui = ["#9b59b6", "#3498db", '#a9a9a9', '#008000', '#b8860b', '#7b68ee']
sns.set_palette(sns.color_palette(flatui))

# %%
ccm_df_base=pd.read_csv(dctry+'CCM_bodytohead_base_2.csv').dropna()   #read Body_head

df2=pd.read_csv(dctry+'CCM_control.csv').dropna()   #read Shuffled Control


ccm_df_base2=ccm_df_base.append(df2)

ccm_bth_base=ccm_df_base2
#plot using seaborn

# %%
g=sns.lineplot(x='dimention', y='score', hue='treatment', data=ccm_df_base2)
#plt.legend(frameon=False)
plt.legend([],[], frameon=False)
plt.xlim(0,40)
plt.ylim(-1,1)
plt.xlabel('Dimensions', fontsize='large')
plt.ylabel('Causal Influence', fontsize='large')
plt.title('Body to Head', fontsize='large')
sns.despine()

plt.savefig('ccm_lines_bth.svg')

# %%
flatui = ["#9b59b6", "#3498db", '#a9a9a9', '#008000', '#b8860b', '#7b68ee']
sns.set_palette(sns.color_palette(flatui))


fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_df_base2.loc[ccm_df_base2['dimention'].isin([6])], ax=ax1,
        order=[ 'SHM', 'LES', 'Shuffled'])
sns.despine()
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)
plt.ylabel('Causal Influence', fontsize='large')
#plt.title('Dimension 7')
plt.xlim(-.7, 3.5)
plt.ylim(-.15, 0.6)
plt.savefig('ccm_base_bodytoh.svg')

# %%
flatui = ["#9b59b6", "#3498db", '#a9a9a9', '#008000', '#b8860b', '#7b68ee']
sns.set_palette(sns.color_palette(flatui))


fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_df_base2.loc[ccm_df_base2['dimention'].isin([7])], ax=ax1,
        order=[ 'SHM', 'LES', 'Shuffled'])
sns.despine(top=True, left=True, right=True)
plt.yticks([],[])

plt.ylabel('')
plt.xlabel('')
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)
plt.xlim(-.7, 3.5)
plt.ylim(-0.1, 1)
# Out:
# (-0.1, 1.0)

# %%
ccm_df_base=pd.read_csv(dctry+'CCM_headtobody_base_2.csv').dropna()   #read Body_head

df2=pd.read_csv(dctry+'CCM_control.csv').dropna()   #read Shuffled Control


ccm_df_base2=ccm_df_base.append(df2)



ccm_htb_base=ccm_df_base2


sns.lineplot(x='dimention', y='score', hue='treatment', data=ccm_df_base2)



plt.xlim(0,40)
plt.ylim(-1,1)
plt.xlabel('Dimensions', fontsize='large')
plt.ylabel('Causal Influence', fontsize='large')
plt.title('Head to Body')
sns.despine()
plt.legend(frameon=False)
plt.savefig('ccm_lines_bth.svg')

# %%
flatui = ["#9b59b6", "#3498db", '#a9a9a9', '#008000', '#b8860b', '#7b68ee']
sns.set_palette(sns.color_palette(flatui))


fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_df_base2.loc[ccm_df_base2['dimention'].isin([6])], ax=ax1,
        order=[ 'SHM', 'LES', 'Shuffled'])
sns.despine()
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)
plt.ylabel('Causal Influence', fontsize='large')
#plt.title('Dimension 7')
plt.xlim(-.7, 3.5)
plt.ylim(-.15, 0.6)
plt.savefig('ccm_base_headtob.svg')

# %%
flatui = ["#9b59b6", "#3498db", '#a9a9a9', '#008000', '#b8860b', '#7b68ee']
sns.set_palette(sns.color_palette(flatui))


fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_df_base2.loc[ccm_df_base2['dimention'].isin([7])], ax=ax1,
        order=[ 'SHM', 'LES', 'Shuffled'])
sns.despine(top=True, right=True)

#plt.yticks([],[])

plt.ylabel('Causal Influence')
plt.xlabel('')
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)
plt.xlim(-.7, 3.5)
plt.ylim(-0.1, 0.6)
# Out:
# (-0.1, 0.6)

# %%
import matplotlib.colors as clr

clr.to_hex('darkgreen')
# Out:
# '#006400'

# %%
flatui = ['gray', '#87ceeb', '#0000ff', '#ee82ee']
sns.set_palette(sns.color_palette(flatui))
sns.color_palette()
# Out:
# [(0.5019607843137255, 0.5019607843137255, 0.5019607843137255),
#  (0.5294117647058824, 0.807843137254902, 0.9215686274509803),
#  (0.0, 0.0, 1.0),
#  (0.9333333333333333, 0.5098039215686274, 0.9333333333333333)]

# %%
# LID '#ee82ee'

# 'SKF', 'D1A', 'D2A', 'LID'

flatui = ['dimgray', 'darkgreen', 'blue', 'darkviolet']
sns.set_palette(sns.color_palette(flatui))


ccm_df_base=pd.read_csv(dctry+'CCM_headtobody_Treatments.csv').dropna()   #read Body_head


ccm_df_base=ccm_df_base.append(ccm_df_base2)
#ccm_df_base2=ccm_df_base.append(df2)

ccm_df_base['treatment'].replace(['SKF', 'D1A', 'D2A'], ['D1+', 'D1-','D2-'], inplace=True)

sns.lineplot(x='dimention', y='score', hue='treatment', data=ccm_df_base.loc[ccm_df_base['treatment'].isin(['LID', 'D1+', 'D1-', 'D2-'])])

plt.xlim(0,40)
plt.ylim(-1,1)
plt.xlabel('Dimensions', fontsize='large')
plt.title('Head to Body', fontsize='large' )
plt.ylabel('Causal Influence', fontsize='large')
plt.legend(frameon=False)
sns.despine()
plt.savefig('CCM_treat_HtB.svg')

# %%
# Out:
# <bound method NDFrame.keys of      Unnamed: 0 treatment     score  dimention
# 0             0       SKF  0.763992          0
# 1             1       SKF  0.797876          1
# 2             2       SKF  0.806958          2
# 3             3       SKF  0.813842          3
# 4             4       SKF  0.813526          4
# ..          ...       ...       ...        ...
# 811         811  Shuffled -0.024894         63
# 812         812  Shuffled -0.025079         64
# 813         813  Shuffled -0.023792         65
# 814         814  Shuffled -0.023650         66
# 815         815  Shuffled -0.024061         67
#
# [5284 rows x 4 columns]>

# %%
# 'SKF', 'D1A', 'D2A', 'LID'

flatui = ['silver', 'darkseagreen', 'steelblue', 'plum']
sns.set_palette(sns.color_palette(flatui))

fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_df_base.loc[ccm_df_base['dimention'].isin([3])], ax=ax1,
        order=['D1+', 'D1-','D2-', 'LID'])
sns.despine()
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)

plt.ylabel('Predicted Length', fontsize='large')
plt.xlabel('')
#plt.title('Dimension 7', fontsize='large')
plt.xlim(-.7, 3.5)
plt.ylim(-.1, 1)

plt.savefig('CCM_treat_HtB_bars.svg')

# %%
ccm_df_base=pd.read_csv(dctry+'CCM_bodytohead_treatment_2.csv').dropna()   #read Body_head

ccm_bth_treat=ccm_df_base.append(ccm_bth_base)

flatui = ['dimgray', 'darkgreen', 'blue', 'darkviolet']
sns.set_palette(sns.color_palette(flatui)) 


sns.lineplot(x='dimention', y='score', hue='treatment', data=ccm_bth_treat.loc                                                   
                                     [ccm_bth_treat['treatment'].isin([ 'LID', 'SKF', 'D1A', 'D2A'])])


#ccm_bth_base=ccm_df_base



plt.xlim(0,40)
plt.ylim(-1,1)
plt.xlabel('Dimensions', fontsize='large')
plt.ylabel('Causal Influence', fontsize='large')
plt.title('Body to Head', fontsize='large')
plt.legend(frameon=False)
sns.despine()

plt.savefig('CCM_treat_BtH.svg')

# %%
ccm_bth_base.head()
# Out:
#    Unnamed: 0 treatment     score  dimention
# 0           0       LES  0.261724          0
# 1           1       LES  0.311559          1
# 2           2       LES  0.397804          2
# 3           3       LES  0.413359          3
# 4           4       LES  0.414565          4

# %%
flatui = ['silver', 'darkseagreen', 'steelblue', 'plum']
sns.set_palette(sns.color_palette(flatui))

fig1 = plt.figure(figsize=(4, 5))
ax1=fig1.add_subplot(111)


sns.barplot(x='treatment', y='score', data=ccm_bth_treat.loc[ccm_bth_treat['dimention'].isin([3])], ax=ax1,
        order=['SKF', 'D1A', 'D2A', 'LID'])
sns.despine()
plt.plot([-.7, 3.5],[0,0], linestyle='--', linewidth=2.0, color='black', alpha=0.5)

plt.ylabel('Predicted Length', fontsize='large')
plt.xlabel('')
#plt.title('Dimension 7', fontsize='large')
plt.xlim(-.7, 3.5)
plt.ylim(-.1, 1)

plt.savefig('CCM_treat_BtH_bars.svg')

# %%
from scipy import stats
import numpy as np

#ccm_bth_base

g1=np.array(ccm_bth_base['score'].loc[(ccm_bth_base['treatment']=='LD6') & (ccm_bth_base['dimention']==20)])
g2=np.array(ccm_bth_base['score'].loc[(ccm_bth_base['treatment']=='LID') & (ccm_bth_base['dimention']==20)])

print(stats.kruskal(g1,g2)[1])
print(stats.ttest_ind(g1,g2)[1])
# Out:
# nan
# nan
